# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu
import pandas as pd

# Perguntas traduzidas pelo Google Tradutor
google_translations = [
    "How many patients were admitted last month?",
    "Which patients were hospitalized more than once in the last year?",
    "How many hospitalizations had complications during treatment?",
    "Which hospitalizations resulted in death in the last trimester?",
    "What is the bed occupancy rate at the 'São José' hospital?",
    "What are the most common ICDs among patients admitted to the Cardiology department?",
    "How many patients under 12 years of age were admitted to the Pediatrics department?",
    "What is the average number of days of hospitalization per patient?",
    "What are the main reasons for admission to Hospital Luz?",
    "Which patients were discharged due to improvement after antibiotic treatment?",
    "What is the hospital readmission rate within 30 days of discharge?",
    "What were the top 5 ICDs for hospitalizations in the last six months?",
    "What are the 3 most prescribed medications for patients with heart failure?",
    "How many imaging tests have been performed in the last 6 months?",
    "Which tests resulted in a conduct to be evaluated?",
    "What is the number of patients admitted due to emergency and scheduled appointments?",
    "Who are the 10 patients with the most hospitalizations in the last year?",
    "Which doctors performed the most treatments this month?",
    "What hospitalizations occurred at the 'Universitário de Brasília' hospital?",
    "How many patients were discharged with complications during their hospital stay?",
    "How many pediatric beds are currently occupied?",
    "Which patients have a history of hypertension and were admitted with complications?",
    "What treatments were applied to patients with diabetes mellitus?",
    "Which hospitals had the most Emergency Department admissions?",
    "Which admissions resulted in transfers to another hospital in the last quarter?"
]

# Perguntas originais (manualmente traduzidas para o inglês)
original_translations = [
    "How many patients were admitted in the last month?",
    "Which patients were admitted more than once in the last year?",
    "How many admissions had complications during treatment?",
    "Which admissions resulted in death in the last quarter?",
    "What is the bed occupancy rate at 'São José' hospital?",
    "What are the most common ICDs among patients admitted to the Cardiology department?",
    "How many patients under 12 years old were admitted to the Pediatrics department?",
    "What is the average length of stay per patient?",
    "What are the main reasons for admission at Luz hospital?",
    "Which patients were discharged after improvement following antibiotic treatment?",
    "What is the hospital readmission rate within 30 days after discharge?",
    "What were the top 5 ICDs for admissions in the last semester?",
    "What are the 3 most prescribed medications for patients with heart failure?",
    "How many imaging exams were performed in the last 6 months?",
    "Which exams resulted in a conduct to be evaluated?",
    "What is the number of patients admitted through emergency and scheduled consultations?",
    "Who are the 10 patients with the most admissions in the last year?",
    "Which doctors performed the most treatments this month?",
    "Which admissions occurred at the 'Universitário de Brasília' hospital?",
    "How many patients were discharged with complications during hospitalization?",
    "How many pediatric beds are currently occupied?",
    "Which patients have a history of hypertension and were admitted with complications?",
    "What treatments were applied to patients with diabetes mellitus?",
    "Which hospitals had the most admissions in the Emergency department?",
    "Which admissions resulted in transfers to another hospital in the last quarter?"
]

# Calcular BLEU Score para cada pergunta
bleu_scores_google = [sentence_bleu([ref.split()], trans.split()) for ref, trans in zip(original_translations, google_translations)]

# Criar DataFrame para exibição
df_bleu_google = pd.DataFrame({
    "Pergunta Original (EN)": original_translations,
    "Tradução Google": google_translations,
    "BLEU Score": bleu_scores_google
})

# Exibir DataFrame no Colab
df_bleu_google
# Out:
#                                Pergunta Original (EN)  \
# 0   How many patients were admitted in the last mo...
# 1   Which patients were admitted more than once in...
# 2   How many admissions had complications during t...
# 3   Which admissions resulted in death in the last...
# 4   What is the bed occupancy rate at 'São José' h...
# 5   What are the most common ICDs among patients a...
# 6   How many patients under 12 years old were admi...
# 7     What is the average length of stay per patient?
# 8   What are the main reasons for admission at Luz...
# 9   Which patients were discharged after improveme...
# 10  What is the hospital readmission rate within 3...
# 11  What were the top 5 ICDs for admissions in the...
# 12  What are the 3 most prescribed medications for...
# 13  How many imaging exams were performed in the l...
# 14  Which exams resulted in a conduct to be evalua...
# 15  What is the number of patients admitted throug...
# 16  Who are the 10 patients with the most admissio...
# 17  Which doctors performed the most treatments th...
# 18  Which admissions occurred at the 'Universitári...
# 19  How many patients were discharged with complic...
# 20    How many pediatric beds are currently occupied?
# 21  Which patients have a history of hypertension ...
# 22  What treatments were applied to patients with ...
# 23  Which hospitals had the most admissions in the...
# 24  Which admissions resulted in transfers to anot...
#
#                                       Tradução Google  BLEU Score
# 0         How many patients were admitted last month?    0.531375
# 1   Which patients were hospitalized more than onc...    0.701688
# 2   How many hospitalizations had complications du...    0.488923
# 3   Which hospitalizations resulted in death in th...    0.610474
# 4   What is the bed occupancy rate at the 'São Jos...    0.701688
# 5   What are the most common ICDs among patients a...    1.000000
# 6   How many patients under 12 years of age were a...    0.699752
# 7   What is the average number of days of hospital...    0.289978
# 8   What are the main reasons for admission to Hos...    0.638943
# 9   Which patients were discharged due to improvem...    0.335689
# 10  What is the hospital readmission rate within 3...    0.807056
# 11  What were the top 5 ICDs for hospitalizations ...    0.578357
# 12  What are the 3 most prescribed medications for...    1.000000
# 13  How many imaging tests have been performed in ...    0.531073
# 14  Which tests resulted in a conduct to be evalua...    0.750624
# 15  What is the number of patients admitted due to...    0.578357
# 16  Who are the 10 patients with the most hospital...    0.761161
# 17  Which doctors performed the most treatments th...    1.000000
# 18  What hospitalizations occurred at the 'Univers...    0.725980
# 19  How many patients were discharged with complic...    0.678650
# 20    How many pediatric beds are currently occupied?    1.000000
# 21  Which patients have a history of hypertension ...    1.000000
# 22  What treatments were applied to patients with ...    1.000000
# 23  Which hospitals had the most Emergency Departm...    0.421395
# 24  Which admissions resulted in transfers to anot...    1.000000

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu
import pandas as pd

# Perguntas originais (manualmente traduzidas para o inglês)
original_translations = [
    "How many patients were admitted in the last month?",
    "Which patients were admitted more than once in the last year?",
    "How many admissions had complications during treatment?",
    "Which admissions resulted in death in the last quarter?",
    "What is the bed occupancy rate at 'São José' hospital?",
    "What are the most common ICDs among patients admitted to the Cardiology department?",
    "How many patients under 12 years old were admitted to the Pediatrics department?",
    "What is the average length of stay per patient?",
    "What are the main reasons for admission at Luz hospital?",
    "Which patients were discharged after improvement following antibiotic treatment?",
    "What is the hospital readmission rate within 30 days after discharge?",
    "What were the top 5 ICDs for admissions in the last semester?",
    "What are the 3 most prescribed medications for patients with heart failure?",
    "How many imaging exams were performed in the last 6 months?",
    "Which exams resulted in a conduct to be evaluated?",
    "What is the number of patients admitted through emergency and scheduled consultations?",
    "Who are the 10 patients with the most admissions in the last year?",
    "Which doctors performed the most treatments this month?",
    "Which admissions occurred at the 'Universitário de Brasília' hospital?",
    "How many patients were discharged with complications during hospitalization?",
    "How many pediatric beds are currently occupied?",
    "Which patients have a history of hypertension and were admitted with complications?",
    "What treatments were applied to patients with diabetes mellitus?",
    "Which hospitals had the most admissions in the Emergency department?",
    "Which admissions resulted in transfers to another hospital in the last quarter?"
]

# Perguntas traduzidas pelo Libre Translate
libre_translations = [
    "How many patients were admitted in the last month?",
    "What patients were hospitalized more than once in the last year?",
    "How many hospitals had complications during treatment?",
    "What hospitalizations resulted in death in the last quarter?",
    "What is the bed occupancy index in the 'Saint Joseph' hospital?",
    "What are the most common ICDs among patients admitted to the Department of Cardiology?",
    "How many patients under 12 were admitted to the Department of Pediatrics?",
    "What is the average of days of hospitalization per patient?",
    "What are the main reasons for hospitalization in the Luz hospital?",
    "What patients have had high for improvement after an antibiotic treatment?",
    "What is the hospital readmission rate within 30 days after discharge?",
    "What were the top 5 ICDs of admissions in the last semester?",
    "What are the 3 most prescribed medicines for patients with heart failure?",
    "How many imaging tests have been performed in the last 6 months?",
    "What tests resulted in a conduct being evaluated?",
    "What is the number of patients admitted by emergency and by scheduled appointments?",
    "Who are the 10 most hospitalized patients in the last year?",
    "What doctors have performed more treatments this month?",
    "What were the hospital admissions in the hospital 'Universitário de Brasília'?",
    "How many patients were discharged with complications during hospitalization?",
    "How many pediatric beds are currently occupied?",
    "What patients have history of hypertension and have been hospitalized with complications?",
    "What treatments have been applied to patients with diabetes mellitus?",
    "What hospitals have had more hospitalizations in the Emergency Department?",
    "What hospitals resulted in transfers to another hospital in the last quarter?"
]

# Calcular BLEU Score para cada pergunta (Libre Translate)
bleu_scores_libre = [sentence_bleu([ref.split()], trans.split()) for ref, trans in zip(original_translations, libre_translations)]

# Criar DataFrame para exibição
df_bleu_libre = pd.DataFrame({
    "Pergunta Original (EN)": original_translations,
    "Tradução Libre": libre_translations,
    "BLEU Score": bleu_scores_libre
})

# Exibir DataFrame no Colab
df_bleu_libre
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#                                Pergunta Original (EN)  \
# 0   How many patients were admitted in the last mo...
# 1   Which patients were admitted more than once in...
# 2   How many admissions had complications during t...
# 3   Which admissions resulted in death in the last...
# 4   What is the bed occupancy rate at 'São José' h...
# 5   What are the most common ICDs among patients a...
# 6   How many patients under 12 years old were admi...
# 7     What is the average length of stay per patient?
# 8   What are the main reasons for admission at Luz...
# 9   Which patients were discharged after improveme...
# 10  What is the hospital readmission rate within 3...
# 11  What were the top 5 ICDs for admissions in the...
# 12  What are the 3 most prescribed medications for...
# 13  How many imaging exams were performed in the l...
# 14  Which exams resulted in a conduct to be evalua...
# 15  What is the number of patients admitted throug...
# 16  Who are the 10 patients with the most admissio...
# 17  Which doctors performed the most treatments th...
# 18  Which admissions occurred at the 'Universitári...
# 19  How many patients were discharged with complic...
# 20    How many pediatric beds are currently occupied?
# 21  Which patients have a history of hypertension ...
# 22  What treatments were applied to patients with ...
# 23  Which hospitals had the most admissions in the...
# 24  Which admissions resulted in transfers to anot...
#
#                                        Tradução Libre     BLEU Score
# 0   How many patients were admitted in the last mo...   1.000000e+00
# 1   What patients were hospitalized more than once...   6.315552e-01
# 2   How many hospitals had complications during tr...   4.889230e-01
# 3   What hospitalizations resulted in death in the...   7.259795e-01
# 4   What is the bed occupancy index in the 'Saint ...   3.672056e-01
# 5   What are the most common ICDs among patients a...   7.577396e-01
# 6   How many patients under 12 were admitted to th...   4.886103e-01
# 7   What is the average of days of hospitalization...   3.246679e-01
# 8   What are the main reasons for hospitalization ...   5.193072e-01
# 9   What patients have had high for improvement af...  6.887578e-155
# 10  What is the hospital readmission rate within 3...   1.000000e+00
# 11  What were the top 5 ICDs of admissions in the ...   7.348889e-01
# 12  What are the 3 most prescribed medicines for p...   7.348889e-01
# 13  How many imaging tests have been performed in ...   5.310725e-01
# 14  What tests resulted in a conduct being evaluated?   3.226014e-01
# 15  What is the number of patients admitted by eme...   5.344446e-01
# 16  Who are the 10 most hospitalized patients in t...   4.136818e-01
# 17  What doctors have performed more treatments th...   5.072841e-78
# 18  What were the hospital admissions in the hospi...  6.513869e-155
# 19  How many patients were discharged with complic...   1.000000e+00
# 20    How many pediatric beds are currently occupied?   1.000000e+00
# 21  What patients have history of hypertension and...   2.864629e-01
# 22  What treatments have been applied to patients ...   5.814307e-01
# 23  What hospitals have had more hospitalizations ...   4.192789e-78
# 24  What hospitals resulted in transfers to anothe...   8.070557e-01
